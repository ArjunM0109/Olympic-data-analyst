# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
athletes = pd.read_csv(r'C:\Users\acer\Desktop\Python\Data Science\Projects\EDA2\Notebook\data\athlete_events.csv')
region = pd.read_csv(r'C:\Users\acer\Desktop\Python\Data Science\Projects\EDA2\Notebook\data\noc_regions.csv')

# %%
athletes.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
region.head(3)
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN

# %%
df = pd.merge(athletes,region,on='NOC')

# %%
df.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal   region notes
# 0   Basketball Men's Basketball   NaN    China   NaN
# 1  Judo Men's Extra-Lightweight   NaN    China   NaN
# 2       Football Men's Football   NaN  Denmark   NaN

# %%
df.shape
# Out:
# (270767, 17)

# %%
df.duplicated().sum()
# Out:
# 1385

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (269382, 17)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9303
# Height     58726
# Weight     61437
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229619
# region        21
# notes     264347
# dtype: int64

# %%
df['Medal'].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df['Medal'].fillna('No-Medal',inplace=True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_10332\1284757070.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Medal'].fillna('No-Medal',inplace=True)

# %%
print(df['Medal'].isnull().sum())
print(df['Medal'].unique())
# Out:
# 0
# ['No-Medal' 'Gold' 'Bronze' 'Silver']

# %%
df['Season'].value_counts()
# Out:
# Season
# Summer    220818
# Winter     48564
# Name: count, dtype: int64

# %%
Summer = df[df['Season']=='Summer']
Winter = df[df['Season']=='Winter']

# %%
print(Summer.shape)
print(Winter.shape)
# Out:
# (220818, 17)
# (48564, 17)

# %% [markdown]
# # 1 Season wise Medal tally

# %%
Summer.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event     Medal  \
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball  No-Medal
#
#   region notes
# 0  China   NaN

# %%
Summer = Summer.drop_duplicates(subset = ['Team','NOC','Games','City','Sport','Event'])

# %%
Summer.shape
# Out:
# (98657, 17)

# %%
medal_count_summer = Summer.groupby(['NOC','Medal']).size().reset_index(name='count')

# %%
medal_pivot_summer = medal_count_summer.pivot(index='NOC',columns='Medal',values='count')

# %%
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No-Medal  Silver
# NOC
# AFG       2.0   NaN      75.0     NaN
# AHO       NaN   NaN      58.0     1.0
# ALB       NaN   NaN      57.0     NaN
# ALG       7.0   4.0     359.0     1.0
# AND       NaN   NaN      45.0     NaN
# ..        ...   ...       ...     ...
# YEM       NaN   NaN      32.0     NaN
# YMD       NaN   NaN       5.0     NaN
# YUG      24.0  19.0     608.0    27.0
# ZAM       1.0   NaN     137.0     1.0
# ZIM       1.0   3.0     204.0     4.0
#
# [229 rows x 4 columns]

# %%
medal_pivot_summer.fillna(0,inplace=True)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No-Medal  Silver
# NOC
# AFG       2.0   0.0      75.0     0.0
# AHO       0.0   0.0      58.0     1.0
# ALB       0.0   0.0      57.0     0.0
# ALG       7.0   4.0     359.0     1.0
# AND       0.0   0.0      45.0     0.0
# ..        ...   ...       ...     ...
# YEM       0.0   0.0      32.0     0.0
# YMD       0.0   0.0       5.0     0.0
# YUG      24.0  19.0     608.0    27.0
# ZAM       1.0   0.0     137.0     1.0
# ZIM       1.0   3.0     204.0     4.0
#
# [229 rows x 4 columns]

# %%
medal_pivot_summer = medal_pivot_summer.astype(int)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No-Medal  Silver
# NOC
# AFG         2     0        75       0
# AHO         0     0        58       1
# ALB         0     0        57       0
# ALG         7     4       359       1
# AND         0     0        45       0
# ..        ...   ...       ...     ...
# YEM         0     0        32       0
# YMD         0     0         5       0
# YUG        24    19       608      27
# ZAM         1     0       137       1
# ZIM         1     3       204       4
#
# [229 rows x 4 columns]

# %%
medal_pivot_summer['Total Medals'] = medal_pivot_summer[['Gold', 'Silver', 'Bronze']].sum(axis=1)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No-Medal  Silver  Total Medals
# NOC
# AFG         2     0        75       0             2
# AHO         0     0        58       1             1
# ALB         0     0        57       0             0
# ALG         7     4       359       1            12
# AND         0     0        45       0             0
# ..        ...   ...       ...     ...           ...
# YEM         0     0        32       0             0
# YMD         0     0         5       0             0
# YUG        24    19       608      27            70
# ZAM         1     0       137       1             2
# ZIM         1     3       204       4             8
#
# [229 rows x 5 columns]

# %%
medal_pivot_summer.sort_values(by=['Gold','Silver','Bronze'],ascending=False,inplace=True)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No-Medal  Silver  Total Medals
# NOC
# USA       371   622      3037     398          1391
# URS       179   279       873     206           664
# GBR       202   182      3157     207           591
# GER       207   177      2093     186           570
# FRA       212   163      3071     166           541
# ..        ...   ...       ...     ...           ...
# VIN         0     0        33       0             0
# VNM         0     0        38       0             0
# YAR         0     0        11       0             0
# YEM         0     0        32       0             0
# YMD         0     0         5       0             0
#
# [229 rows x 5 columns]

# %%
Winter.shape
# Out:
# (48564, 17)

# %%
Winter = Winter.drop_duplicates(subset = ['Team','NOC','Games','City','Sport','Event'])

# %%
Winter.shape
# Out:
# (16956, 17)

# %%
medal_count_winter = Winter.groupby(['NOC','Medal']).size().reset_index(name='count')

# %%
medal_pivot_winter = medal_count_winter.pivot(index='NOC',columns='Medal',values='count')

# %%
medal_pivot_winter.head(3)
# Out:
# Medal  Bronze  Gold  No-Medal  Silver
# NOC
# AHO       NaN   NaN       3.0     NaN
# ALB       NaN   NaN       7.0     NaN
# ALG       NaN   NaN       9.0     NaN

# %%
medal_pivot_winter.fillna(0,inplace=True)

# %%
medal_pivot_winter = medal_pivot_winter.astype(int)
medal_pivot_winter.head(3)
# Out:
# Medal  Bronze  Gold  No-Medal  Silver
# NOC
# AHO         0     0         3       0
# ALB         0     0         7       0
# ALG         0     0         9       0

# %%
medal_pivot_winter['Total Medals'] = medal_pivot_winter[['Gold','Silver','Bronze']].sum(axis=1)

# %%
medal_pivot_winter
# Out:
# Medal  Bronze  Gold  No-Medal  Silver  Total Medals
# NOC
# AHO         0     0         3       0             0
# ALB         0     0         7       0             0
# ALG         0     0         9       0             0
# AND         0     0        69       0             0
# ARG         0     0       169       0             0
# ..        ...   ...       ...     ...           ...
# USA        44    39       894      48           131
# UZB         0     1        26       0             1
# VEN         0     0         5       0             0
# YUG         1     0       167       1             2
# ZIM         0     0         2       0             0
#
# [119 rows x 5 columns]

# %%
medal_pivot_winter.sort_values(by=['Gold','Silver','Bronze'],ascending=False,inplace=True)

# %%
medal_pivot_winter
# Out:
# Medal  Bronze  Gold  No-Medal  Silver  Total Medals
# NOC
# NOR        48    58       529      43           149
# URS        24    46       216      24            94
# CAN        25    43       770      34           102
# USA        44    39       894      48           131
# GER        36    39       534      38           113
# ..        ...   ...       ...     ...           ...
# TTO         0     0         3       0             0
# TUR         0     0        79       0             0
# URU         0     0         1       0             0
# VEN         0     0         5       0             0
# ZIM         0     0         2       0             0
#
# [119 rows x 5 columns]

# %% [markdown]
# # Country Wise Medal tally

# %%
def fatch_noc(noc, pivot_table):
    # Check if the NOC exists in the index of the pivot table
    if noc in pivot_table.index:
        details = {
            'Gold': pivot_table.loc[noc, 'Gold'],
            'Silver': pivot_table.loc[noc, 'Silver'],
            'Bronze': pivot_table.loc[noc, 'Bronze'],
            'Total-Medals': pivot_table.loc[noc, 'Total Medals']
        }
        return details
    else:
        # Return None or an empty dictionary if the NOC does not exist
        print('No NOC exists!')
        return None

# %%
fatch_noc("CAN",medal_pivot_winter)
# Out:
# {'Gold': 43, 'Silver': 34, 'Bronze': 25, 'Total-Medals': 102}

# %% [markdown]
# # Year Wise Search

# %%
Summer.shape
# Out:
# (98657, 17)

# %%
Summer.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        3119
# Height    17827
# Weight    18182
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# region       20
# notes     96593
# dtype: int64

# %%
Summer.dropna(subset=['region'],inplace=True)

# %%
Summer.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        3118
# Height    17823
# Weight    18180
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# region        0
# notes     96593
# dtype: int64

# %%
medal_count = Summer.groupby(['Year','region','Medal']).size().unstack(fill_value=0)

# %%
medal_count
# Out:
# Medal                         Bronze  Gold  No-Medal  Silver
# Year region
# 1896 Australia                     1     2         2       0
#      Austria                       2     2         3       1
#      Denmark                       3     1         6       2
#      France                        2     1        11       4
#      Germany                       1     4        21       1
# ...                              ...   ...       ...     ...
# 2016 Virgin Islands, British       0     0         4       0
#      Virgin Islands, US            0     0         7       0
#      Yemen                         0     0         3       0
#      Zambia                        0     0         7       0
#      Zimbabwe                      0     0        13       0
#
# [2769 rows x 4 columns]

# %%
medal_count['Total Medals'] = medal_count[['Gold','Silver','Bronze']].sum(axis=1)

# %%
medal_count = medal_count.reset_index()

# %%
medal_count
# Out:
# Medal  Year                   region  Bronze  Gold  No-Medal  Silver  \
# 0      1896                Australia       1     2         2       0
# 1      1896                  Austria       2     2         3       1
# 2      1896                  Denmark       3     1         6       2
# 3      1896                   France       2     1        11       4
# 4      1896                  Germany       1     4        21       1
# ...     ...                      ...     ...   ...       ...     ...
# 2764   2016  Virgin Islands, British       0     0         4       0
# 2765   2016       Virgin Islands, US       0     0         7       0
# 2766   2016                    Yemen       0     0         3       0
# 2767   2016                   Zambia       0     0         7       0
# 2768   2016                 Zimbabwe       0     0        13       0
#
# Medal  Total Medals
# 0                 3
# 1                 5
# 2                 6
# 3                 7
# 4                 6
# ...

# %%
import matplotlib.pyplot as plt

def plot_medals(year, country, df):
    filtered_df = df[(df['Year'] == year) & (df['region'] == country)]
    if filtered_df.empty:
        print(f"No data available for {country} in {year}.")
        return
        
    gold = filtered_df['Gold'].values[0]
    silver = filtered_df['Silver'].values[0]
    bronze = filtered_df['Bronze'].values[0]
    total_medals = filtered_df['Total Medals'].values[0]
    
    medals = [gold, silver, bronze,total_medals]
    labels = ['Gold', 'Silver', 'Bronze','Total_Medal']
    colors = ['#FFD700', '#C0C0C0', '#CD7F32','g']  # gold, silver, bronze colors
    # Plotting the medals
    plt.figure(figsize=(8, 6))
    plt.bar(labels, medals, color=colors)
    plt.title(f"{country} Medals in {year}")
    plt.xlabel("Type of Medal")
    plt.ylabel("Number of Medals")
    plt.ylim(0, max(medals) + 5)  # Add some space above the highest bar
    plt.show()

# %%
plot_medals(1996,'Denmark',medal_count)

# %% [markdown]
# # 3. Year Wise Progress of country

# %%
def plot_year_progress(country, df): 
    # Filter the DataFrame for the specified country
    filtered_df = df[df['region'] == country]
    
    # Plot each medal type over the years
    plt.figure(figsize=(10, 6))  # Create a new figure with a specified size
    plt.plot(filtered_df['Year'], filtered_df['Gold'], color='gold', label='Gold')
    plt.plot(filtered_df['Year'], filtered_df['Silver'], color='silver', label='Silver')
    plt.plot(filtered_df['Year'], filtered_df['Bronze'], color='brown', label='Bronze')
    plt.plot(filtered_df['Year'], filtered_df['Total Medals'], color='green', label='Total Medals')
    
    # Add legend, title, and labels
    plt.legend()
    plt.title(f"Medal Progress for {country} Over the Years")  # Use plt.title instead of plt.set_title
    plt.xlabel("Year")  # Use plt.xlabel instead of plt.set_xlabel
    plt.ylabel("Number of Medals")  # Use plt.ylabel instead of plt.set_ylabel
    
    # Display the plot
    plt.show()

# %%
plot_year_progress('Denmark',medal_count)
